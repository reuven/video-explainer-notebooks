# %%
t = (10, 20, 30, 40, 50)

# %%
t.index(30)  # where does 30 appear?
# Out:
# 2

# %%
t[2]
# Out:
# 30

# %%
t = (10, 20, 30, 20, 30, 40, 20, 30, 40, 50)
t.index(30)
# Out:
# 2

# %%
t[2]
# Out:
# 30

# %%
t.count(30)  # how many times does 30 appear?
# Out:
# 3

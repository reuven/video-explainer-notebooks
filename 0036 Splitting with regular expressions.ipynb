# %%
import re

# %%
# RegexpCrashCourse.com

# %%
s = 'abc,def,ghi,jkl'

s.split(',')
# Out:
# ['abc', 'def', 'ghi', 'jkl']

# %%
s = 'abc def ghi jkl'

s.split(' ')
# Out:
# ['abc', 'def', 'ghi', 'jkl']

# %%
s.split('f')
# Out:
# ['abc de', ' ghi jkl']

# %%
s.split('ef')
# Out:
# ['abc d', ' ghi jkl']

# %%
s = 'abc def,ghi jkl'

s.split(' ')
# Out:
# ['abc', 'def,ghi', 'jkl']

# %%
s.split(',')
# Out:
# ['abc def', 'ghi jkl']

# %%
re.split('[ ,]', s)
# Out:
# ['abc', 'def', 'ghi', 'jkl']

# %%
re.split('[ ,]', s, 1)
# Out:
# ['abc', 'def,ghi jkl']

# %%
re.split()

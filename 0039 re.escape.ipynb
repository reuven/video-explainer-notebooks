# %%
import re

# %%
# RegexpCrashCourse.com

# %%
s = 'Hello?? Is anyone there??'

re.findall(re.escape('Hello??'), s)
# Out:
# ['Hello??']

# %%
re.findall(re.escape('\w+??'), s)
# Out:
# []

# %%
re.escape('Hello??')
# Out:
# 'Hello\\?\\?'
